# %% [markdown]
# #Øving 4 Funksjoner i Python

# %% [markdown]
# ##Oppgave 1
# Lag en funksjon i med Python-kode slik at du kan regne ut $f(1)$, $f(2)$ og $f(4)$ når $f(x)$ er gitt som $$f(x) = \dfrac{x^{2x} + x^2}{x^{x}+2^x}$$

# %%
#Skriv inn programkoden din under her

# %% [markdown]
# ##Oppgave 2
# Skriv ut verditabellen til funksjonen under. Sjekk definisjonsmengden, og del den opp i 20 deler. $$g(x) = x^3 - 3x^2 + 3x - 1  ,  D_g = [-3,7]$$
#
#
#
#
# Hint: Bruk `np.linspace(-3,7,21)`. Den gir 21 verdier, og dermed blir definisjonsmengden delt opp i 20

# %%
# Skriv inn programkoden din under her

# %% [markdown]
# ##Oppgave 3
# Du skal til USA, leser deg litt opp, og lurer på hvor store avstandene er. De amerikanske nettstedene oppgir alle verdier i *miles*, men du vil gjerne vite antall km.
#
# Lag et program som spør brukeren om å skrive inn en avstand i miles, for så å returnere den i km.
#
# Bruk formelen: $Antall\ km = Antall\ miles \cdot 1,609344$

# %%
# Skriv inn programkoden din under her

# %% [markdown]
# ##Oppgave 4
# I fysikken sier vi at et objekt som er i bevegelse har kinetisk energi. Kinetisk energi er gitt ved $E_k = \frac{1}{2} mv^2$, der $m$ er massen til objektet og $v$ er hastigheten.
#
# Lag en funksjon som bruker objektets masse og hastighet som inn-verdier, og som returnerer objektets kinetiske energi.

# %%
# Skriv koden til programmet ditt her

# %% [markdown]
# ##Oppgave 5
# I økt 4 så fikk du presentert en `is_prime` funksjon som ble brukt for å sjekke om noe er et primtall.
#
# ```
# def is_prime(x):
#     if x < 2:
#         return False
#     else:
#         for n in range(2,x):       # her bruker vi også range-kommandoen, og da sjekkes alle verdier fra og med 2 til x
#             if x % n == 0:
#                return False
#         return True
# ```
# Skriv et nytt program som skriver ut alle primtall fra 1 til 100.
#
# Her bør du lage en løkke som kaller opp `is_prime` funksjonen. (Husk at du må definere denne i din programkode under for at du skal kunne bruke denne)

# %%
# Skriv koden til programmet ditt her
