# %% [markdown]
# # Dette er et første forsøk på å skrive markdown og kode i VSCode
# Det var ganske enkelt å åpne en ny fil i en GitHub-mappe

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0,20,101)
plt.plot(x, np.sin(x))
plt.show()

# %%
import matplotlib.pyplot as plt

x = [21,22,23,4,5,6,77,8,9,10,31,32,33,34,35,36,37,18,49,50,100]
num_bins = 5
n, bins, patches = plt.hist(x, num_bins, facecolor='blue', alpha = 0.5)
plt.show()

# %%
x = [21,22,23,4,5,6,77,8,9,10,31,32,33,34,35,36,37,18,49,50,100]
num_bins = 10
n, bins, patches = plt.hist(x, num_bins, facecolor='blue', alpha = 0.5)
plt.show()
